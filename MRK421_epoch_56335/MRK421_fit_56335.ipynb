# %%
""" Starting  packages import (copy-paste) """
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import matplotlib.pylab as plt
import jetset
from jetset.data_loader import ObsData,Data
from jetset.plot_sedfit import PlotSED
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # 1. Import data and shaping

# %% [markdown]
# ## 1.1 Importing the SED data from the observation started at 56335 (MJD) or 12.02.2013

# %%
sed_data = ObsData(data_table=Data.from_file('sed_mrk421_mjd_56335.ecsv'))

# %% [markdown]
# ## 1.2 Preliminary plot of the data and rebinning (standard)

# %%
# Plot data
myPlot=sed_data.plot_sed()

# Data rebin in bins of 10^{0.2} [Hz]
sed_data.group_data(bin_width=0.2)
sed_data.add_systematics(0.1,[10.**6,10.**29])

# Plotting rebinned data
myPlot.add_data_plot(sed_data,label='rebinned')

# Standard rescale that will be kept for the different pre-fits and fits
myPlot.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# ===================================================================================================================
#
# ***  binning data  ***
# ---> N bins= 87
# ---> bin_widht= 0.2
# ===================================================================================================================
# /home/aramis/miniconda3/envs/jetset/lib/python3.7/site-packages/astropy/table/table.py:1195: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   newcol = col[slice_]

# %% [markdown]
# ## 1.3 First shaping for different bands (expected power law, report section 2.2.2)

# %%
from jetset.sed_shaper import  SEDShape

# Selecting the SED data to shape
my_shape=SEDShape(sed_data)

# Indices evaluation
my_shape.eval_indices(silent=True)

# Plot the shaping
p=my_shape.plot_indices()

# Rescale with standard axis size
p.rescale(y_min=-14,y_max=-8)

# Show spectral indices
my_shape.show_values()
# Out:
# ===================================================================================================================
#
# *** evaluating spectral indices for data ***
# ===================================================================================================================
#
# ===================================================================================================================
#
# *** SEDShape values ***
# ---> spectral inidces values
# ---> name = radio            range=[6.000 ,10.000] log(Hz)  photon.val=-1.148521e+00, err=1.741983e-02
# ---> name = radio_mm         range=[10.000,11.000] log(Hz)  photon.val=-1.013701e+00, err=6.155573e-02
# ---> name = mm_IR            range=[10.400,13.600] log(Hz)  photon.val=-1.033539e+00, err=2.092705e-01
# ---> name = IR_Opt           range=[13.000,14.000] log(Hz)  photon.val=No           , err=No
# ---> name = Opt_UV           range=[12.900,17.100] log(Hz)  photon.val=-1.825695e+00, err=7.362916e-02
# ---> name = BBB              range=[13.900,17.100] log(Hz)  photon.val=-1.825695e+00, err=7.362916e-02
# ---> name = UV_X             range=[15.000,17.500] log(Hz)  photon.val=-1.944970e+00, err=4.224389e-02
# ---> name = X                range=[16.000,19.000] log(Hz)  photon.val=-2.594645e+00, err=3.225009e-02
# ---> name = Fermi            range=[22.380,25.380] log(Hz)  photon.val=-1.852916e+00, err=3.116236e-02
# ---> name = TeV              range=[25.000,28.380] log(Hz)  photon.val=-2.523136e+00, err=7.010456e-02
#
#
# ---> S/IC peak values
# ---> sync       nu_p=No            (err=No           )  nuFnu_p=No            (err=No           ) curv.=No            (err=No           )
#
# ---> IC         nu_p=No            (err=No           )  nuFnu_p=No            (err=No           ) curv.=No            (err=No           )
#
#
# ===================================================================================================================

# %% [markdown]
# # 2. Separed fits and prefit

# %% [markdown]
# ## 2.1 Fit with Synchrotron and Inverse Compton bumps (separated), without considering any galactic contribution to the flux. For further information about logparep, see:
# ### <i>E. Massaro, A. Tramacere et al., Log-parabolic spectra and particle acceleration in blazars, A&A 448, 861–871 (2006)<i>

# %%
# Chosing best fit 1 with minuit (first line for synchrotron, second line for IC)
mm,best_fit1_minuit=my_shape.sync_fit(check_host_gal_template=False,  Ep_start=None, minimizer='minuit', silent=True, fit_range=[9.9,19.5], use_log_par=True)
my_shape.IC_fit(fit_range=[22.5,27],minimizer='minuit')


# Plot fit 
p=my_shape.plot_shape_fit()

# Standard rescaling
p.rescale(y_min=-14)
p.rescale(y_max=-8)
p.rescale(x_min=9)
p.rescale(x_max=27.5)
# Out:
# ===================================================================================================================
#
# *** Log-Polynomial fitting of the synchrotron component ***
# ---> first blind fit run,  fit range: [9.9, 19.5]
# ---> class:  HSP
#
#
#
#   model name  name  bestfit val     err +     err -   start val   fit range min fit range max frozen
# ------------- ---- ------------- ------------ ----- ------------- ------------- ------------- ------
# LogParabolaEp    b -1.026553e-01 2.085202e-03    -- -1.000000e+00 -1.000000e+01  0.000000e+00  False
# LogParabolaEp   Ep  1.602640e+01 4.270300e-02    --  1.629636e+01  0.000000e+00  3.000000e+01  False
# LogParabolaEp   Sp -9.580351e+00 2.251564e-02    -- -1.000000e+01 -3.000000e+01  0.000000e+00  False
# ---> sync       nu_p=+1.602640e+01 (err=+4.270300e-02)  nuFnu_p=-9.580351e+00 (err=+2.251564e-02) curv.=-1.026553e-01 (err=+2.085202e-03)
# ===================================================================================================================
#
# ===================================================================================================================
#
# *** Log-Polynomial fitting of the IC component ***
# ---> fit range: [22.5, 27]
# ---> LogCubic fit
#
# **************************************************************************************************
# Fit report
#
# Model: IC-shape-fit
# model name name   par type       units          val      phys. bound. min phys. bound. max  log  frozen
# ---------- ---- ------------ ------------- ------------- ---------------- ---------------- ----- ------
#   LogCubic    b    curvature               -2.180762e-01    -1.000000e+01     0.000000e+00 False  False
#   LogCubic    c third-degree               -5.813440e-02    -1.000000e+01     1.000000e+01 False  False
#   LogCubic   Ep    peak freq            Hz  2.488890e+01     0.000000e+00     3.000000e+01  True  False
#   LogCubic   Sp    peak flux erg / (cm2 s) -1.009658e+01    -3.000000e+01     0.000000e+00  True  False
#
# converged=True
# calls=56
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 1.888                      │         Nfcn = 55 (55 total)         │
# │ EDM = 9.62e-09 (Goal: 0.0002)    │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │ Valid Minimum │ Valid Parameters │        No Parameters at limit        │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name  │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_0 │   -0.22   │   0.05    │            │            │   -10   │    0    │       │
# │ 1 │ par_1 │  -0.058   │   0.031   │            │            │   -10   │   10    │       │
# │ 2 │ par_2 │   24.89   │   0.19    │            │            │    0    │   30    │       │
# │ 3 │ par_3 │  -10.10   │   0.05    │            │            │   -30   │    0    │       │
# └───┴───────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# dof=6
# chisq=1.888208, chisq/red=0.314701 null hypothesis sig=0.929687
#
# best fit pars
# model name name  bestfit val     err +     err -   start val   fit range min fit range max frozen
# ---------- ---- ------------- ------------ ----- ------------- ------------- ------------- ------
#   LogCubic    b -2.180762e-01 5.054353e-02    -- -1.000000e+00 -1.000000e+01  0.000000e+00  False
#   LogCubic    c -5.813440e-02 3.084370e-02    -- -1.000000e+00 -1.000000e+01  1.000000e+01  False
#   LogCubic   Ep  2.488890e+01 1.937783e-01    --  2.484116e+01  0.000000e+00  3.000000e+01  False
#   LogCubic   Sp -1.009658e+01 5.373478e-02    -- -1.000000e+01 -3.000000e+01  0.000000e+00  False
# **************************************************************************************************
#
#
#
# model name name  bestfit val     err +     err -   start val   fit range min fit range max frozen
# ---------- ---- ------------- ------------ ----- ------------- ------------- ------------- ------
#   LogCubic    b -2.180762e-01 5.054353e-02    -- -1.000000e+00 -1.000000e+01  0.000000e+00  False
#   LogCubic    c -5.813440e-02 3.084370e-02    -- -1.000000e+00 -1.000000e+01  1.000000e+01  False
#   LogCubic   Ep  2.488890e+01 1.937783e-01    --  2.484116e+01  0.000000e+00  3.000000e+01  False
#   LogCubic   Sp -1.009658e+01 5.373478e-02    -- -1.000000e+01 -3.000000e+01  0.000000e+00  False
# ---> IC         nu_p=+2.488890e+01 (err=+1.937783e-01)  nuFnu_p=-1.009658e+01 (err=+5.373478e-02) curv.=-2.180762e-01 (err=+5.054353e-02)
# ===================================================================================================================

# %% [markdown]
# ## 2.2 Prefit of the entire SED, by constraining 4 parameters with the chosen literature values (<i>Balokovic et al. 2016<i>).
#
# <i>The time duration of the measurement is said to be almost 12 hr, which is expressed with the time of 43200 sec. A model is built and saved as a .pkl file at the end of the prefit procedure.  <i>

# %%
# Import constraining and model menager features
from jetset.obs_constrain import ObsConstrain
from jetset.model_manager import  FitModel

# Constraining parameters of beaming, which is standardly fixed at 25 in Blaokovic et al., 
# fixing the max/ min range found in literature for all 4 epochs,
# 12 hr obsercation time
# nu cut at 10^{13}
sed_obspar=ObsConstrain(beaming=25,
                        B_range=[0.05,0.3],
                        distr_e='lppl',
                        t_var_sec=43200,
                        nu_cut_IR=1E13,
                        SEDShape=my_shape)

# Creating a empty prefit with the constrained parameters (Synchrotron-self-Compton model used)
prefit_jet=sed_obspar.constrain_SSC_model(electron_distribution_log_values=False, silent=True)

# Evaluating prefit
prefit_jet.eval()

# Inserting the data in a .pkl file
prefit_jet.save_model('prefit_jet_gal_templ.pkl')

# Prefit plot 
pl=prefit_jet.plot_model(sed_data=sed_data)

# Residual plot (chi)
pl.add_residual_plot(prefit_jet,sed_data)

# Standard
pl.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# ===================================================================================================================
#
# ***  constrains parameters from observable ***
# /home/aramis/miniconda3/envs/jetset/lib/python3.7/site-packages/jetset-1.1.2-py3.7-linux-x86_64.egg/jetset/obs_constrain.py:481: RankWarning: Polyfit may be poorly conditioned
#   B_from_nu_peaks,failed=constr_B_from_nu_peaks (jet_model,self.nu_p_S_obs,self.nu_p_IC_obs,self.rest_frame,self.B_min,self.B_max,self.beaming,params_grid_size,silent=silent)
#       name             par type           units          val      phys. bound. min phys. bound. max  log  frozen
# ---------------- ------------------- --------------- ------------ ---------------- ---------------- ----- ------
#             gmin  low-energy-cut-off lorentz-factor* 9.470323e+02     1.000000e+00     1.000000e+09 False  False
#             gmax high-energy-cut-off lorentz-factor* 7.885748e+05     1.000000e+00     1.000000e+15 False  False
#                N    emitters_density         1 / cm3 2.077013e+00     0.000000e+00               -- False  False
#                s   LE_spectral_slope                 2.327303e+00    -1.000000e+01     1.000000e+01 False  False
#                r  spectral_curvature                 5.132763e-01    -1.500000e+01     1.500000e+01 False  False
# gamma0_log_parab    turn-over-energy lorentz-factor* 6.827586e+03     1.000000e+00     1.000000e+09 False  False
#                R         region_size              cm 1.459163e+16     1.000000e+03     1.000000e+30 False  False
#              R_H     region_position              cm 1.000000e+17     0.000000e+00               -- False   True
#                B      magnetic_field               G 1.242519e-01     0.000000e+00               -- False  False
#         beam_obj             beaming Lorentz-factor* 2.500000e+01     1.000000e-04               -- False  False
#           z_cosm            redshift                 3.080000e-02     0.000000e+00               -- False  False
#
# ===================================================================================================================

# %% [markdown]
# ## 2.3 Prefit parameters table

# %%
prefit_jet.parameters.par_table
# Out:
# <Table length=11>
#       name             par type           units      ...  log  frozen
#      str16              str19             object     ...  bool  bool
# ---------------- ------------------- --------------- ... ----- ------
#             gmin  low-energy-cut-off lorentz-factor* ... False  False
#             gmax high-energy-cut-off lorentz-factor* ... False  False
#                N    emitters_density         1 / cm3 ... False  False
#                s   LE_spectral_slope                 ... False  False
#                r  spectral_curvature                 ... False  False
# gamma0_log_parab    turn-over-energy lorentz-factor* ... False  False
#                R         region_size              cm ... False  False
#              R_H     region_position              cm ... False   True
#                B      magnetic_field               G ... False  False
#         beam_obj             beaming Lorentz-factor* ... False  False
#           z_cosm            redshift                 ... False  False

# %% [markdown]
# ## 2.4 Writing down prefit parameters in a new model MRK421_56392

# %%
from jetset.jet_model import Jet
jet_MRK421_56302=Jet.load_model('prefit_jet_gal_templ.pkl')
# Out:
#       name             par type           units          val      phys. bound. min phys. bound. max  log  frozen
# ---------------- ------------------- --------------- ------------ ---------------- ---------------- ----- ------
#             gmin  low-energy-cut-off lorentz-factor* 9.470323e+02     1.000000e+00     1.000000e+09 False  False
#             gmax high-energy-cut-off lorentz-factor* 7.885748e+05     1.000000e+00     1.000000e+15 False  False
#                N    emitters_density         1 / cm3 2.077013e+00     0.000000e+00               -- False  False
#                s   LE_spectral_slope                 2.327303e+00    -1.000000e+01     1.000000e+01 False  False
#                r  spectral_curvature                 5.132763e-01    -1.500000e+01     1.500000e+01 False  False
# gamma0_log_parab    turn-over-energy lorentz-factor* 6.827586e+03     1.000000e+00     1.000000e+09 False  False
#                R         region_size              cm 1.459163e+16     1.000000e+03     1.000000e+30 False  False
#              R_H     region_position              cm 1.000000e+17     0.000000e+00               -- False   True
#                B      magnetic_field               G 1.242519e-01     0.000000e+00               -- False  False
#         beam_obj             beaming Lorentz-factor* 2.500000e+01     1.000000e-04               -- False  False
#           z_cosm            redshift                 3.080000e-02     0.000000e+00               -- False  False

# %% [markdown]
# # 3. Broadband SED fit

# %% [markdown]
# ## 3.1 Lsb minimizer fit, with range setting according to chosen literature (<i>Balokovic et al. 2016<i>).

# %%
# Import minimizers
from jetset.minimizer import ModelMinimizer
from jetset.model_manager import  FitModel

# Loading model from prefit
jet_lsb=Jet.load_model('prefit_jet_gal_templ.pkl')

# Choosing grid size
jet_lsb.set_gamma_grid_size(200)

# Declaring the fit "fit_model_lsb" and its denomination (graph)
fit_model_lsb=FitModel(jet=jet_lsb, name='SSC-best-fit-lsb',template=None) 
# Freezing the redshift
fit_model_lsb.freeze(jet_lsb,'z_cosm')
# Freezing region position
fit_model_lsb.freeze(jet_lsb,'R_H')

# Choosing ranges for fit from chosen literature 
fit_model_lsb.jet_leptonic.parameters.beam_obj.fit_range=[5,80]
fit_model_lsb.jet_leptonic.parameters.R.fit_range=[10**15.5,10**17.5]
fit_model_lsb.jet_leptonic.parameters.gmax.fit_range=[1E5,1E7]
fit_model_lsb.jet_leptonic.parameters.gmin.fit_range=[10,1E4]
fit_model_lsb.jet_leptonic.nu_size=200
fit_model_lsb.jet_leptonic.IC_nu_size=100
fit_model_lsb.jet_leptonic._blob.adaptive_e_binning=0

# Model minimizer choosen lsb
model_minimizer_lsb=ModelMinimizer('lsb')

# Selecting best fit among the repetitions and creating the corresponding model
best_fit_lsb=model_minimizer_lsb.fit(fit_model_lsb,sed_data,1E10,1E29,fitname='SSC-best-fit-lsb',repeat=3)

# Plotting the fit along with the Mrk421 data
# %matplotlib inline
fit_model_lsb.set_nu_grid(1E6,1E30,200)

# Evaluating the final model
fit_model_lsb.eval()
p2=fit_model_lsb.plot_model(sed_data=sed_data)

# Standard rescaling
p2.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
#       name             par type           units          val      phys. bound. min phys. bound. max  log  frozen
# ---------------- ------------------- --------------- ------------ ---------------- ---------------- ----- ------
#             gmin  low-energy-cut-off lorentz-factor* 9.470323e+02     1.000000e+00     1.000000e+09 False  False
#             gmax high-energy-cut-off lorentz-factor* 7.885748e+05     1.000000e+00     1.000000e+15 False  False
#                N    emitters_density         1 / cm3 2.077013e+00     0.000000e+00               -- False  False
#                s   LE_spectral_slope                 2.327303e+00    -1.000000e+01     1.000000e+01 False  False
#                r  spectral_curvature                 5.132763e-01    -1.500000e+01     1.500000e+01 False  False
# gamma0_log_parab    turn-over-energy lorentz-factor* 6.827586e+03     1.000000e+00     1.000000e+09 False  False
#                R         region_size              cm 1.459163e+16     1.000000e+03     1.000000e+30 False  False
#              R_H     region_position              cm 1.000000e+17     0.000000e+00               -- False   True
#                B      magnetic_field               G 1.242519e-01     0.000000e+00               -- False  False
#         beam_obj             beaming Lorentz-factor* 2.500000e+01     1.000000e-04               -- False  False
#           z_cosm            redshift                 3.080000e-02     0.000000e+00               -- False  False
# filtering data in fit range = [1.000000e+10,1.000000e+29]
# data length 28
# ===================================================================================================================
#
# *** start fit process ***
# -----
# fit run: 0
# /home/aramis/miniconda3/envs/jetset/lib/python3.7/site-packages/jetset-1.1.2-py3.7-linux-x86_64.egg/jetset/model_manager.py:160: UserWarning: no cosmology defined, using default FlatLambdaCDM(name="Planck13", H0=67.8 km / (Mpc s), Om0=0.307, Tcmb0=2.725 K, Neff=3.05, m_nu=[0.   0.   0.06] eV, Ob0=0.0483)
#   warnings.warn('no cosmology defined, using default %s'%self.cosmo)
# / minim function calls=60, chisq=329.282036 UL part=-0.000000
# fit run: 1
# - minim function calls=50, chisq=132.645886 UL part=-0.000000
# fit run: 2
# | minim function calls=20, chisq=131.627844 UL part=-0.000000
# **************************************************************************************************
# Fit report
#
# Model: SSC-best-fit-lsb
#  model name        name             par type           units          val      phys. bound. min phys. bound. max  log  frozen
# ------------ ---------------- ------------------- --------------- ------------ ---------------- ---------------- ----- ------
# jet_leptonic             gmin  low-energy-cut-off lorentz-factor* 5.996389e+02     1.000000e+00     1.000000e+09 False  False
# jet_leptonic             gmax high-energy-cut-off lorentz-factor* 5.106745e+05     1.000000e+00     1.000000e+15 False  False
# jet_leptonic                N    emitters_density         1 / cm3 2.074356e+00     0.000000e+00               -- False  False
# jet_leptonic                s   LE_spectral_slope                 2.438195e+00    -1.000000e+01     1.000000e+01 False  False
# jet_leptonic                r  spectral_curvature                 7.125329e-01    -1.500000e+01     1.500000e+01 False  False
# jet_leptonic gamma0_log_parab    turn-over-energy lorentz-factor* 2.814261e+04     1.000000e+00     1.000000e+09 False  False
# jet_leptonic                R         region_size              cm 2.025985e+16     1.000000e+03     1.000000e+30 False  False
# jet_leptonic              R_H     region_position              cm 1.000000e+17     0.000000e+00               -- False   True
# jet_leptonic                B      magnetic_field               G 8.507698e-02     0.000000e+00               -- False  False
# jet_leptonic         beam_obj             beaming Lorentz-factor* 2.664149e+01     1.000000e-04               -- False  False
# jet_leptonic           z_cosm            redshift                 3.080000e-02     0.000000e+00               -- False   True
#
# converged=True
# calls=26
# The relative error between two consecutive iterates is at most 0.000000
# dof=19
# chisq=131.261641, chisq/red=6.908507 null hypothesis sig=0.000000
#
# best fit pars
#  model name        name       bestfit val     err +     err -  start val   fit range min fit range max frozen
# ------------ ---------------- ------------ ------------ ----- ------------ ------------- ------------- ------
# jet_leptonic             gmin 5.996389e+02 3.840282e+02    -- 9.470323e+02  1.000000e+01  1.000000e+04  False
# jet_leptonic             gmax 5.106745e+05 1.210333e+05    -- 7.885748e+05  1.000000e+05  1.000000e+07  False
# jet_leptonic                N 2.074356e+00 1.788158e+00    -- 2.077013e+00  0.000000e+00            --  False
# jet_leptonic                s 2.438195e+00 4.608804e-01    -- 2.327303e+00 -1.000000e+01  1.000000e+01  False
# jet_leptonic                r 7.125329e-01 6.049056e-01    -- 5.132763e-01 -1.500000e+01  1.500000e+01  False
# jet_leptonic gamma0_log_parab 2.814261e+04 5.122825e+04    -- 6.827586e+03  1.000000e+00  1.000000e+09  False
# jet_leptonic                R 2.025985e+16 7.296869e+15    -- 1.459163e+16  3.162278e+15  3.162278e+17  False
# jet_leptonic              R_H           --           --    -- 1.000000e+17  0.000000e+00            --   True
# jet_leptonic                B 8.507698e-02 5.266941e-02    -- 1.242519e-01  0.000000e+00            --  False
# jet_leptonic         beam_obj 2.664149e+01 1.058158e+01    -- 2.500000e+01  5.000000e+00  8.000000e+01  False
# jet_leptonic           z_cosm           --           --    -- 3.080000e-02  0.000000e+00            --   True
# **************************************************************************************************
#
# ===================================================================================================================

# %% [markdown]
# ## 3.2 Lsb-fit parameters table

# %%
jet_lsb.parameters.par_table
# Out:
# <Table length=11>
#  model name        name             par type      ...  log  frozen
#    str12          str16              str19        ...  bool  bool
# ------------ ---------------- ------------------- ... ----- ------
# jet_leptonic             gmin  low-energy-cut-off ... False  False
# jet_leptonic             gmax high-energy-cut-off ... False  False
# jet_leptonic                N    emitters_density ... False  False
# jet_leptonic                s   LE_spectral_slope ... False  False
# jet_leptonic                r  spectral_curvature ... False  False
# jet_leptonic gamma0_log_parab    turn-over-energy ... False  False
# jet_leptonic                R         region_size ... False  False
# jet_leptonic              R_H     region_position ... False   True
# jet_leptonic                B      magnetic_field ... False  False
# jet_leptonic         beam_obj             beaming ... False  False
# jet_leptonic           z_cosm            redshift ... False   True

# %% [markdown]
# ## 3.3 Modifying lsb fit with a minuit fit

# %%
# Defining model minimizer
model_minimizer_minuit=ModelMinimizer('minuit')

# Defining best fit lsb --> minuit
best_fit_minuit=model_minimizer_minuit.fit(fit_model_lsb,sed_data,1E10,1E29,fitname='SSC-best-fit-lsb',repeat=3)

# Plotting fit (here "fit_model_lsb" corresponds to the fitted model modified by minuit minimizer)
# %matplotlib inline
fit_model_lsb.set_nu_grid(1E6,1E30,200)

# Evaluating fit
fit_model_lsb.eval()
p2=fit_model_lsb.plot_model(sed_data=sed_data)

# Standard rescaling
p2.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# filtering data in fit range = [1.000000e+10,1.000000e+29]
# data length 28
# ===================================================================================================================
#
# *** start fit process ***
# -----
# fit run: 0
# / minim function calls=540, chisq=102.561958 UL part=-0.000000
# fit run: 1
# / minim function calls=1160, chisq=90.041438 UL part=-0.0000000
# fit run: 2
# / minim function calls=280, chisq=90.682965 UL part=-0.000000 part=-0.000000
# **************************************************************************************************
# Fit report
#
# Model: SSC-best-fit-lsb
#  model name        name             par type           units          val      phys. bound. min phys. bound. max  log  frozen
# ------------ ---------------- ------------------- --------------- ------------ ---------------- ---------------- ----- ------
# jet_leptonic             gmin  low-energy-cut-off lorentz-factor* 5.784596e+02     1.000000e+00     1.000000e+09 False  False
# jet_leptonic             gmax high-energy-cut-off lorentz-factor* 6.164553e+05     1.000000e+00     1.000000e+15 False  False
# jet_leptonic                N    emitters_density         1 / cm3 2.624055e+00     0.000000e+00               -- False  False
# jet_leptonic                s   LE_spectral_slope                 2.502743e+00    -1.000000e+01     1.000000e+01 False  False
# jet_leptonic                r  spectral_curvature                 7.571444e-01    -1.500000e+01     1.500000e+01 False  False
# jet_leptonic gamma0_log_parab    turn-over-energy lorentz-factor* 3.817531e+04     1.000000e+00     1.000000e+09 False  False
# jet_leptonic                R         region_size              cm 2.066040e+16     1.000000e+03     1.000000e+30 False  False
# jet_leptonic              R_H     region_position              cm 1.000000e+17     0.000000e+00               -- False   True
# jet_leptonic                B      magnetic_field               G 7.408086e-02     0.000000e+00               -- False  False
# jet_leptonic         beam_obj             beaming Lorentz-factor* 2.697573e+01     1.000000e-04               -- False  False
# jet_leptonic           z_cosm            redshift                 3.080000e-02     0.000000e+00               -- False   True
#
# converged=True
# calls=282
# ┌──────────────────────────────────┬──────────────────────────────────────┐
# │ FCN = 90.04                      │        Nfcn = 281 (281 total)        │
# │ EDM = 0.362 (Goal: 0.0002)       │                                      │
# ├───────────────┬──────────────────┼──────────────────────────────────────┤
# │INVALID Minimum│ Valid Parameters │       SOME Parameters at limit       │
# ├───────────────┴──────────────────┼──────────────────────────────────────┤
# │ ABOVE EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │   Hesse ok    │  Has Covariance  │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name  │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_0 │ 578.4596  │  0.0028   │            │            │   10    │  10000  │       │
# │ 1 │ par_1 │616.4553e3 │ 0.0015e3  │            │            │ 100000  │  1e+07  │       │
# │ 2 │ par_2 │   2.62    │   0.26    │            │            │    0    │         │       │
# │ 3 │ par_3 │   2.50    │   0.04    │            │            │   -10   │   10    │       │
# │ 4 │ par_4 │   0.76    │   0.11    │            │            │   -15   │   15    │       │
# │ 5 │ par_5 │  0.038e6  │  0.011e6  │            │            │    1    │  1e+09  │       │
# │ 6 │ par_6 │ 20.66e15  │  0.24e15  │            │            │3.16228e+15│3.16228e+17│       │
# │ 7 │ par_7 │  0.0741   │  0.0035   │            │            │    0    │         │       │
# │ 8 │ par_8 │   27.0    │    0.8    │            │            │    5    │   80    │       │
# └───┴───────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# dof=19
# chisq=90.041438, chisq/red=4.739023 null hypothesis sig=0.000000
#
# best fit pars
#  model name        name       bestfit val     err +     err -  start val   fit range min fit range max frozen
# ------------ ---------------- ------------ ------------ ----- ------------ ------------- ------------- ------
# jet_leptonic             gmin 5.784596e+02 2.823566e-03    -- 5.996389e+02  1.000000e+01  1.000000e+04  False
# jet_leptonic             gmax 6.164553e+05 1.499190e+00    -- 5.106745e+05  1.000000e+05  1.000000e+07  False
# jet_leptonic                N 2.624055e+00 2.630079e-01    -- 2.074356e+00  0.000000e+00            --  False
# jet_leptonic                s 2.502743e+00 3.749218e-02    -- 2.438195e+00 -1.000000e+01  1.000000e+01  False
# jet_leptonic                r 7.571444e-01 1.097675e-01    -- 7.125329e-01 -1.500000e+01  1.500000e+01  False
# jet_leptonic gamma0_log_parab 3.817531e+04 1.103336e+04    -- 2.814261e+04  1.000000e+00  1.000000e+09  False
# jet_leptonic                R 2.066040e+16 2.386356e+14    -- 2.025985e+16  3.162278e+15  3.162278e+17  False
# jet_leptonic              R_H           --           --    -- 1.000000e+17  0.000000e+00            --   True
# jet_leptonic                B 7.408086e-02 3.472480e-03    -- 8.507698e-02  0.000000e+00            --  False
# jet_leptonic         beam_obj 2.697573e+01 7.851564e-01    -- 2.664149e+01  5.000000e+00  8.000000e+01  False
# jet_leptonic           z_cosm           --           --    -- 3.080000e-02  0.000000e+00            --   True
# **************************************************************************************************
#
# ===================================================================================================================

# %% [markdown]
# ## 3.4 Minuit-fit parameters table

# %%
best_fit_minuit.parameters.par_table
# Out:
# <Table length=11>
#  model name        name             par type      ...  log  frozen
#    str12          str16              str19        ...  bool  bool
# ------------ ---------------- ------------------- ... ----- ------
# jet_leptonic             gmin  low-energy-cut-off ... False  False
# jet_leptonic             gmax high-energy-cut-off ... False  False
# jet_leptonic                N    emitters_density ... False  False
# jet_leptonic                s   LE_spectral_slope ... False  False
# jet_leptonic                r  spectral_curvature ... False  False
# jet_leptonic gamma0_log_parab    turn-over-energy ... False  False
# jet_leptonic                R         region_size ... False  False
# jet_leptonic              R_H     region_position ... False   True
# jet_leptonic                B      magnetic_field ... False  False
# jet_leptonic         beam_obj             beaming ... False  False
# jet_leptonic           z_cosm            redshift ... False   True
