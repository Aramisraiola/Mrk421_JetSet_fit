# %%
""" Starting  packages import (copy-paste) """
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import matplotlib.pylab as plt
import jetset
from jetset.data_loader import ObsData,Data
from jetset.plot_sedfit import PlotSED
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # 1. Import data and shaping

# %% [markdown]
# ## 1.1 Importing the SED data from the observation started at 56335 (MJD) or 12.02.2013

# %%
sed_data = ObsData(data_table=Data.from_file('sed_mrk421_mjd_56335.ecsv'))

# %% [markdown]
# ## 1.2 Preliminary plot of the data and rebinning (standard)

# %%
# Plot data
myPlot=sed_data.plot_sed()

# Data rebin in bins of 10^{0.2} [Hz]
sed_data.group_data(bin_width=0.2)
sed_data.add_systematics(0.1,[10.**6,10.**29])

# Plotting rebinned data
myPlot.add_data_plot(sed_data,label='rebinned')

# Standard rescale that will be kept for the different pre-fits and fits
myPlot.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# ================================================================================
#
# ***  binning data  ***
# ---> N bins= 87
# ---> bin_widht= 0.2
# ================================================================================
# /home/aramis/miniconda3/envs/jetset1.2/lib/python3.8/site-packages/astropy/table/table.py:1195: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   newcol = col[slice_]

# %% [markdown]
# ## 1.3 First shaping for different bands (expected power law, report section 2.2.2)

# %%
from jetset.sed_shaper import  SEDShape

# Selecting the SED data to shape
my_shape=SEDShape(sed_data)

# Indices evaluation
my_shape.eval_indices(silent=True)

# Plot the shaping
p=my_shape.plot_indices()

# Rescale with standard axis size
p.rescale(y_min=-14,y_max=-8)

# Show spectral indices
my_shape.show_values()
# Out:
# ================================================================================
#
# *** evaluating spectral indices for data ***
# ================================================================================
#
# ================================================================================
#
# *** SEDShape values ***
# ---> spectral inidces values
# ---> name = radio            range=[6.000 ,10.000] log(Hz)  photon.val=-1.148521e+00, err=1.741983e-02
# ---> name = radio_mm         range=[10.000,11.000] log(Hz)  photon.val=-1.013701e+00, err=6.155573e-02
# ---> name = mm_IR            range=[10.400,13.600] log(Hz)  photon.val=-1.033539e+00, err=2.092705e-01
# ---> name = IR_Opt           range=[13.000,14.000] log(Hz)  photon.val=No           , err=No
# ---> name = Opt_UV           range=[12.900,17.100] log(Hz)  photon.val=-1.825695e+00, err=7.362916e-02
# ---> name = BBB              range=[13.900,17.100] log(Hz)  photon.val=-1.825695e+00, err=7.362916e-02
# ---> name = UV_X             range=[15.000,17.500] log(Hz)  photon.val=-1.944970e+00, err=4.224389e-02
# ---> name = X                range=[16.000,19.000] log(Hz)  photon.val=-2.594645e+00, err=3.225010e-02
# ---> name = Fermi            range=[22.380,25.380] log(Hz)  photon.val=-1.852916e+00, err=3.116236e-02
# ---> name = TeV              range=[25.000,28.380] log(Hz)  photon.val=-2.523136e+00, err=7.010456e-02
#
#
# ---> S/IC peak values
# ---> sync       nu_p=No            (err=No           )  nuFnu_p=No            (err=No           ) curv.=No            (err=No           )
#
# ---> IC         nu_p=No            (err=No           )  nuFnu_p=No            (err=No           ) curv.=No            (err=No           )
#
#
# ================================================================================

# %% [markdown]
# # 2. Separed fits and prefit

# %% [markdown]
# ## 2.1 Fit with Synchrotron and Inverse Compton bumps (separated), without considering any galactic contribution to the flux. For further information about logparep, see:
# ### <i>E. Massaro, A. Tramacere et al., Log-parabolic spectra and particle acceleration in blazars, A&A 448, 861–871 (2006)<i>

# %%
# Chosing best fit 1 with minuit (first line for synchrotron, second line for IC)
mm,best_fit1_minuit=my_shape.sync_fit(check_host_gal_template=False,  Ep_start=None, minimizer='minuit', silent=True, fit_range=[9,19.5], use_log_par=True)
my_shape.IC_fit(fit_range=[22.5,27],minimizer='minuit')


# Plot fit 
p=my_shape.plot_shape_fit()

# Standard rescaling
p.rescale(y_min=-14)
p.rescale(y_max=-8)
p.rescale(x_min=9)
p.rescale(x_max=27.5)
# Out:
# ================================================================================
#
# *** Log-Polynomial fitting of the synchrotron component ***
# ---> first blind fit run,  fit range: [9, 19.5]
# ---> class:  HSP
# <i>Table length=3</i>
# <table id="table139886058685440-205303" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>val</th><th>bestfit val</th><th>err +</th><th>err -</th><th>start val</th><th>fit range min</th><th>fit range max</th><th>frozen</th></tr></thead>
# <tr><td>LogParabolaEp</td><td>b</td><td>-9.664286e-02</td><td>-9.664286e-02</td><td>1.888295e-03</td><td>--</td><td>-1.000000e+00</td><td>-1.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# <tr><td>LogParabolaEp</td><td>Ep</td><td>1.609058e+01</td><td>1.609058e+01</td><td>4.554251e-02</td><td>--</td><td>1.628349e+01</td><td>0.000000e+00</td><td>3.000000e+01</td><td>False</td></tr>
# <tr><td>LogParabolaEp</td><td>Sp</td><td>-9.621627e+00</td><td>-9.621627e+00</td><td>2.132641e-02</td><td>--</td><td>-1.000000e+01</td><td>-3.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886058685440-205303').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886058685440-205303').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2, 3, 4, 5, 6, 7, 8], type: "optionalnum"}]
#     });
# });
# </script>
# ---> sync       nu_p=+1.609058e+01 (err=+4.554251e-02)  nuFnu_p=-9.621627e+00 (err=+2.132641e-02) curv.=-9.664286e-02 (err=+1.888295e-03)
# ================================================================================
#
# ================================================================================
#
# *** Log-Polynomial fitting of the IC component ***
# ---> fit range: [22.5, 27]
# ---> LogCubic fit
# -------------------------------------------------------------------------
# Fit report
#
# Model: IC-shape-fit
# <i>Table length=4</i>
# <table id="table139886059189728-137714" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>LogCubic</td><td>b</td><td>curvature</td><td></td><td>-2.180762e-01</td><td>-1.000000e+01</td><td>0.000000e+00</td><td>False</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>c</td><td>third-degree</td><td></td><td>-5.813440e-02</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Ep</td><td>peak freq</td><td>Hz</td><td>2.488890e+01</td><td>0.000000e+00</td><td>3.000000e+01</td><td>True</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Sp</td><td>peak flux</td><td>erg / (cm2 s)</td><td>-1.009658e+01</td><td>-3.000000e+01</td><td>0.000000e+00</td><td>True</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886059189728-137714').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886059189728-137714').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>
# converged=True
# calls=56
# mesg=
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 1.888                      │              Nfcn = 56               │
# │ EDM = 9.62e-09 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name  │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_0 │   -0.22   │   0.05    │            │            │   -10   │    0    │       │
# │ 1 │ par_1 │  -0.058   │   0.031   │            │            │   -10   │   10    │       │
# │ 2 │ par_2 │   24.89   │   0.19    │            │            │    0    │   30    │       │
# │ 3 │ par_3 │  -10.10   │   0.05    │            │            │   -30   │    0    │       │
# └───┴───────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────┬─────────────────────────────────────┐
# │       │    par_0    par_1    par_2    par_3 │
# ├───────┼─────────────────────────────────────┤
# │ par_0 │  0.00256  0.00135 -0.00809 0.000256 │
# │ par_1 │  0.00135 0.000951 -0.00557 0.000652 │
# │ par_2 │ -0.00809 -0.00557   0.0376 -0.00591 │
# │ par_3 │ 0.000256 0.000652 -0.00591  0.00289 │
# └───────┴─────────────────────────────────────┘
# dof=6
# chisq=1.888208, chisq/red=0.314701 null hypothesis sig=0.929687
#
# stats without the UL
# dof  UL=6
# chisq=1.888208, chisq/red=0.314701 null hypothesis sig=0.929687
#
#
# best fit pars
# <i>Table length=4</i>
# <table id="table139886059191600-485875" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>val</th><th>bestfit val</th><th>err +</th><th>err -</th><th>start val</th><th>fit range min</th><th>fit range max</th><th>frozen</th></tr></thead>
# <tr><td>LogCubic</td><td>b</td><td>-2.180762e-01</td><td>-2.180762e-01</td><td>5.054178e-02</td><td>--</td><td>-1.000000e+00</td><td>-1.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>c</td><td>-5.813440e-02</td><td>-5.813440e-02</td><td>3.084233e-02</td><td>--</td><td>-1.000000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Ep</td><td>2.488890e+01</td><td>2.488890e+01</td><td>1.937696e-01</td><td>--</td><td>2.484116e+01</td><td>0.000000e+00</td><td>3.000000e+01</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Sp</td><td>-1.009658e+01</td><td>-1.009658e+01</td><td>5.373421e-02</td><td>--</td><td>-1.000000e+01</td><td>-3.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886059191600-485875').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886059191600-485875').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2, 3, 4, 5, 6, 7, 8], type: "optionalnum"}]
#     });
# });
# </script>
# -------------------------------------------------------------------------
# <i>Table length=4</i>
# <table id="table139886062570992-704413" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>val</th><th>bestfit val</th><th>err +</th><th>err -</th><th>start val</th><th>fit range min</th><th>fit range max</th><th>frozen</th></tr></thead>
# <tr><td>LogCubic</td><td>b</td><td>-2.180762e-01</td><td>-2.180762e-01</td><td>5.054178e-02</td><td>--</td><td>-1.000000e+00</td><td>-1.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>c</td><td>-5.813440e-02</td><td>-5.813440e-02</td><td>3.084233e-02</td><td>--</td><td>-1.000000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Ep</td><td>2.488890e+01</td><td>2.488890e+01</td><td>1.937696e-01</td><td>--</td><td>2.484116e+01</td><td>0.000000e+00</td><td>3.000000e+01</td><td>False</td></tr>
# <tr><td>LogCubic</td><td>Sp</td><td>-1.009658e+01</td><td>-1.009658e+01</td><td>5.373421e-02</td><td>--</td><td>-1.000000e+01</td><td>-3.000000e+01</td><td>0.000000e+00</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886062570992-704413').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886062570992-704413').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2, 3, 4, 5, 6, 7, 8], type: "optionalnum"}]
#     });
# });
# </script>
# ---> IC         nu_p=+2.488890e+01 (err=+1.937696e-01)  nuFnu_p=-1.009658e+01 (err=+5.373421e-02) curv.=-2.180762e-01 (err=+5.054178e-02)
# ================================================================================

# %% [markdown]
# ## 2.2 Prefit of the entire SED, by constraining 4 parameters with the chosen literature values (<i>Balokovic et al. 2016<i>).
#
# <i>The time duration of the measurement is said to be almost 12 hr, which is expressed with the time of 43200 sec. A model is built and saved as a .pkl file at the end of the prefit procedure.  <i>

# %%
# Import constraining and model menager features
from jetset.obs_constrain import ObsConstrain
from jetset.model_manager import  FitModel
from jetset.jet_model import Jet

# Constraining parameters of beaming, which is standardly fixed at 25 in Blaokovic et al., 
# fixing the max/ min range found in literature for all 4 epochs,
# 12 hr obsercation time
# nu cut at 10^{13}
sed_obspar=ObsConstrain(B_range=[0.1,0.3],
                        distr_e='bkn',
                        t_var_sec=43200,
                        nu_cut_IR=1E13,
                        bulk_factor=25,
                        theta=2.29,
                        SEDShape=my_shape)

# Creating a empty prefit with the constrained parameters (Synchrotron-self-Compton model used)
prefit_jet=sed_obspar.constrain_SSC_model(electron_distribution_log_values=False, silent=True)

# Evaluating prefit
prefit_jet.eval()

# Inserting the data in a .pkl file
prefit_jet.save_model('prefit_jet_gal_templ.pkl')

# Prefit plot 
pl=prefit_jet.plot_model(sed_data=sed_data)

# Residual plot (chi)
pl.add_residual_plot(prefit_jet,sed_data)

# Standard
pl.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# ================================================================================
#
# ***  constrains parameters from observable ***
# /home/aramis/miniconda3/envs/jetset1.2/lib/python3.8/site-packages/jetset/obs_constrain.py:650: RankWarning: Polyfit may be poorly conditioned
#   return func(*args, **kwargs),completed
# <i>Table length=12</i>
# <table id="table139886051804256-608638" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>R</td><td>region_size</td><td>cm</td><td>8.592124e+15</td><td>1.000000e+03</td><td>1.000000e+30</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>region_position</td><td>cm</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>magnetic_field</td><td>gauss</td><td>1.679097e-01</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>jet-viewing-angle</td><td>deg</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>jet-bulk-factor</td><td>lorentz-factor*</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>redshift</td><td></td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmin</td><td>low-energy-cut-off</td><td>lorentz-factor*</td><td>8.142301e+02</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>high-energy-cut-off</td><td>lorentz-factor*</td><td>6.779931e+05</td><td>1.000000e+00</td><td>1.000000e+15</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>emitters_density</td><td>1 / cm3</td><td>4.614043e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>turn-over-energy</td><td>lorentz-factor*</td><td>2.857841e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>LE_spectral_slope</td><td></td><td>2.327303e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>HE_spectral_slope</td><td></td><td>3.500000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886051804256-608638').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886051804256-608638').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>
# ================================================================================

# %% [markdown]
# ## 2.3 Prefit parameters table

# %%
prefit_jet.parameters.par_table
# Out:
# <Table length=12>
#  model name      name          par type      ... phys. bound. max  log  frozen
#    str12        str11           str19        ...     float64       bool  bool
# ------------ ----------- ------------------- ... ---------------- ----- ------
# jet_leptonic           R         region_size ...     1.000000e+30 False  False
# jet_leptonic         R_H     region_position ...               -- False   True
# jet_leptonic           B      magnetic_field ...               -- False  False
# jet_leptonic       theta   jet-viewing-angle ...               -- False  False
# jet_leptonic  BulkFactor     jet-bulk-factor ...               -- False  False
# jet_leptonic      z_cosm            redshift ...               -- False  False
# jet_leptonic        gmin  low-energy-cut-off ...     1.000000e+09 False  False
# jet_leptonic        gmax high-energy-cut-off ...     1.000000e+15 False  False
# jet_leptonic           N    emitters_density ...               -- False  False
# jet_leptonic gamma_break    turn-over-energy ...     1.000000e+09 False  False
# jet_leptonic           p   LE_spectral_slope ...     1.000000e+01 False  False
# jet_leptonic         p_1   HE_spectral_slope ...     1.000000e+01 False  False

# %% [markdown]
# ## 2.4 Writing down prefit parameters in a new model MRK421_56392

# %%
from jetset.jet_model import Jet
jet_MRK421_56302=Jet.load_model('prefit_jet_gal_templ.pkl')
# Out:
# <i>Table length=12</i>
# <table id="table139886207797376-323841" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>low-energy-cut-off</td><td>lorentz-factor*</td><td>8.142301e+02</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>high-energy-cut-off</td><td>lorentz-factor*</td><td>6.779931e+05</td><td>1.000000e+00</td><td>1.000000e+15</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>emitters_density</td><td>1 / cm3</td><td>4.614043e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>turn-over-energy</td><td>lorentz-factor*</td><td>2.857841e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>LE_spectral_slope</td><td></td><td>2.327303e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>HE_spectral_slope</td><td></td><td>3.500000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>region_size</td><td>cm</td><td>8.592124e+15</td><td>1.000000e+03</td><td>1.000000e+30</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>region_position</td><td>cm</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>magnetic_field</td><td>gauss</td><td>1.679097e-01</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>jet-viewing-angle</td><td>deg</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>jet-bulk-factor</td><td>lorentz-factor*</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>redshift</td><td></td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886207797376-323841').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886207797376-323841').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>

# %% [markdown]
# # 3. Broadband SED fit

# %% [markdown]
# ## 3.1 Lsb minimizer fit, with range setting according to chosen literature (<i>Balokovic et al. 2016<i>).

# %%
# Import minimizers
from jetset.minimizer import ModelMinimizer
from jetset.model_manager import  FitModel

# Loading model from prefit
jet_lsb=Jet.load_model('prefit_jet_gal_templ.pkl')

# Choosing grid size
jet_lsb.set_gamma_grid_size(200)

# Declaring the fit "fit_model_lsb" and its denomination (graph)
fit_model_lsb=FitModel(jet=jet_lsb, name='SSC-best-fit-lsb',template=None) 
# Freezing the redshift
fit_model_lsb.freeze(jet_lsb,'z_cosm')
# Freezing region position
fit_model_lsb.freeze(jet_lsb,'R_H')
# Freezing viewing angle
fit_model_lsb.freeze(jet_lsb,'theta')
# Freezing Lorentz gamma factor
fit_model_lsb.freeze(jet_lsb,'BulkFactor')

# Choosing ranges for fit from chosen literature 
fit_model_lsb.jet_leptonic.parameters.R.fit_range=[10**15.5,1.1E16]
fit_model_lsb.jet_leptonic.parameters.gmax.fit_range=[1E5,1E8]
fit_model_lsb.jet_leptonic.parameters.gmin.fit_range=[10,1E4]

fit_model_lsb.jet_leptonic.nu_size=200
fit_model_lsb.jet_leptonic.IC_nu_size=100
fit_model_lsb.jet_leptonic._blob.adaptive_e_binning=0

# Model minimizer choosen lsb
model_minimizer_lsb=ModelMinimizer('lsb')

# Selecting best fit among the repetitions and creating the corresponding model
best_fit_lsb=model_minimizer_lsb.fit(fit_model_lsb,sed_data,10**10.5,1E29,fitname='SSC-best-fit-lsb',repeat=3)

# Plotting the fit along with the Mrk421 data
# %matplotlib inline
fit_model_lsb.set_nu_grid(1E6,1E30,200)

# Evaluating the final model
fit_model_lsb.eval()
p2=fit_model_lsb.plot_model(sed_data=sed_data)

# Standard rescaling
p2.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# <i>Table length=12</i>
# <table id="table139886208115472-112518" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>low-energy-cut-off</td><td>lorentz-factor*</td><td>8.142301e+02</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>high-energy-cut-off</td><td>lorentz-factor*</td><td>6.779931e+05</td><td>1.000000e+00</td><td>1.000000e+15</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>emitters_density</td><td>1 / cm3</td><td>4.614043e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>turn-over-energy</td><td>lorentz-factor*</td><td>2.857841e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>LE_spectral_slope</td><td></td><td>2.327303e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>HE_spectral_slope</td><td></td><td>3.500000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>region_size</td><td>cm</td><td>8.592124e+15</td><td>1.000000e+03</td><td>1.000000e+30</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>region_position</td><td>cm</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>magnetic_field</td><td>gauss</td><td>1.679097e-01</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>jet-viewing-angle</td><td>deg</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>jet-bulk-factor</td><td>lorentz-factor*</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>redshift</td><td></td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886208115472-112518').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886208115472-112518').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>
# filtering data in fit range = [3.162278e+10,1.000000e+29]
# data length 25
# ================================================================================
#
# *** start fit process ***
# -----
# fit run: 0
# /home/aramis/miniconda3/envs/jetset1.2/lib/python3.8/site-packages/jetset/model_manager.py:147: UserWarning: no cosmology defined, using default FlatLambdaCDM(name="Planck13", H0=67.8 km / (Mpc s), Om0=0.307, Tcmb0=2.725 K, Neff=3.05, m_nu=[0.   0.   0.06] eV, Ob0=0.0483)
#   warnings.warn('no cosmology defined, using default %s'%self.cosmo)
# 0it [00:00, ?it/s]
# - best chisq=1.78773e+01
#
# fit run: 1
# - old chisq=1.78773e+01
# 0it [00:00, ?it/s]
# - best chisq=1.78773e+01
#
# fit run: 2
# - old chisq=1.78773e+01
# 0it [00:00, ?it/s]
# - best chisq=1.78773e+01
#
# -------------------------------------------------------------------------
# Fit report
#
# Model: SSC-best-fit-lsb
# <i>Table length=12</i>
# <table id="table139886059155168-376933" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>low-energy-cut-off</td><td>lorentz-factor*</td><td>2.783989e+02</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>high-energy-cut-off</td><td>lorentz-factor*</td><td>5.349663e+05</td><td>1.000000e+00</td><td>1.000000e+15</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>emitters_density</td><td>1 / cm3</td><td>7.237391e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>turn-over-energy</td><td>lorentz-factor*</td><td>5.299423e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>LE_spectral_slope</td><td></td><td>2.211115e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>HE_spectral_slope</td><td></td><td>3.898049e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>region_size</td><td>cm</td><td>1.099993e+16</td><td>1.000000e+03</td><td>1.000000e+30</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>region_position</td><td>cm</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>magnetic_field</td><td>gauss</td><td>1.534407e-01</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>jet-viewing-angle</td><td>deg</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>jet-bulk-factor</td><td>lorentz-factor*</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>redshift</td><td></td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886059155168-376933').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886059155168-376933').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>
# converged=True
# calls=17
# mesg=
# 'The relative error between two consecutive iterates is at most 0.000000'
# dof=17
# chisq=17.877316, chisq/red=1.051607 null hypothesis sig=0.396620
#
# best fit pars
# <i>Table length=12</i>
# <table id="table139886207558704-228243" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>val</th><th>bestfit val</th><th>err +</th><th>err -</th><th>start val</th><th>fit range min</th><th>fit range max</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>2.783989e+02</td><td>2.783989e+02</td><td>7.737982e+01</td><td>--</td><td>8.142301e+02</td><td>1.000000e+01</td><td>1.000000e+04</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>5.349663e+05</td><td>5.349663e+05</td><td>5.740575e+04</td><td>--</td><td>6.779931e+05</td><td>1.000000e+05</td><td>1.000000e+08</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>7.237391e+00</td><td>7.237391e+00</td><td>2.405934e+00</td><td>--</td><td>4.614043e+00</td><td>0.000000e+00</td><td>--</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>5.299423e+04</td><td>5.299423e+04</td><td>1.145967e+04</td><td>--</td><td>2.857841e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>2.211115e+00</td><td>2.211115e+00</td><td>1.267538e-01</td><td>--</td><td>2.327303e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>3.898049e+00</td><td>3.898049e+00</td><td>1.330750e-01</td><td>--</td><td>3.500000e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>1.099993e+16</td><td>1.099993e+16</td><td>9.755903e+14</td><td>--</td><td>8.592124e+15</td><td>3.162278e+15</td><td>1.100000e+16</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>1.000000e+17</td><td>--</td><td>--</td><td>--</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>1.534407e-01</td><td>1.534407e-01</td><td>1.565822e-02</td><td>--</td><td>1.679097e-01</td><td>0.000000e+00</td><td>--</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>2.290000e+00</td><td>--</td><td>--</td><td>--</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>2.500000e+01</td><td>--</td><td>--</td><td>--</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>3.080000e-02</td><td>--</td><td>--</td><td>--</td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886207558704-228243').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886207558704-228243').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2, 3, 4, 5, 6, 7, 8], type: "optionalnum"}]
#     });
# });
# </script>
# -------------------------------------------------------------------------
#
# ================================================================================

# %% [markdown]
# ## 3.2 Lsb-fit parameters table

# %%
jet_lsb.parameters.par_table
# Out:
# <Table length=12>
#  model name      name          par type      ... phys. bound. max  log  frozen
#    str12        str11           str19        ...     float64       bool  bool
# ------------ ----------- ------------------- ... ---------------- ----- ------
# jet_leptonic        gmin  low-energy-cut-off ...     1.000000e+09 False  False
# jet_leptonic        gmax high-energy-cut-off ...     1.000000e+15 False  False
# jet_leptonic           N    emitters_density ...               -- False  False
# jet_leptonic gamma_break    turn-over-energy ...     1.000000e+09 False  False
# jet_leptonic           p   LE_spectral_slope ...     1.000000e+01 False  False
# jet_leptonic         p_1   HE_spectral_slope ...     1.000000e+01 False  False
# jet_leptonic           R         region_size ...     1.000000e+30 False  False
# jet_leptonic         R_H     region_position ...               -- False   True
# jet_leptonic           B      magnetic_field ...               -- False  False
# jet_leptonic       theta   jet-viewing-angle ...               -- False   True
# jet_leptonic  BulkFactor     jet-bulk-factor ...               -- False   True
# jet_leptonic      z_cosm            redshift ...               -- False   True

# %% [markdown]
# ## 3.3 Modifying lsb fit with a minuit fit

# %%
# Defining model minimizer
model_minimizer_minuit=ModelMinimizer('minuit')

# Defining best fit lsb --> minuit
best_fit_minuit=model_minimizer_minuit.fit(fit_model_lsb,sed_data,10**10.5,1E29,fitname='SSC-best-fit-minuit',repeat=3)

# Plotting fit (here "fit_model_lsb" corresponds to the fitted model modified by minuit minimizer)
# %matplotlib inline
fit_model_lsb.set_nu_grid(1E6,1E30,200)

# Evaluating fit
fit_model_lsb.eval()
p2=fit_model_lsb.plot_model(sed_data=sed_data)

# Standard rescaling
p2.rescale(y_min=-14,y_max=-8,x_min=9,x_max=27.5)
# Out:
# filtering data in fit range = [3.162278e+10,1.000000e+29]
# data length 25
# ================================================================================
#
# *** start fit process ***
# -----
# fit run: 0
# 0it [00:00, ?it/s]
# - best chisq=1.78772e+01
#
# fit run: 1
# - old chisq=1.78772e+01
# 0it [00:00, ?it/s]
# - best chisq=1.78772e+01
#
# fit run: 2
# - old chisq=1.78772e+01
# 0it [00:00, ?it/s]
# - best chisq=1.78772e+01
#
# -------------------------------------------------------------------------
# Fit report
#
# Model: SSC-best-fit-minuit
# <i>Table length=12</i>
# <table id="table139887429058032-398104" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>par type</th><th>units</th><th>val</th><th>phys. bound. min</th><th>phys. bound. max</th><th>log</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>low-energy-cut-off</td><td>lorentz-factor*</td><td>2.783970e+02</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>high-energy-cut-off</td><td>lorentz-factor*</td><td>5.349704e+05</td><td>1.000000e+00</td><td>1.000000e+15</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>emitters_density</td><td>1 / cm3</td><td>7.237438e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>turn-over-energy</td><td>lorentz-factor*</td><td>5.299415e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>LE_spectral_slope</td><td></td><td>2.211115e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>HE_spectral_slope</td><td></td><td>3.898054e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>region_size</td><td>cm</td><td>1.100000e+16</td><td>1.000000e+03</td><td>1.000000e+30</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>region_position</td><td>cm</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>magnetic_field</td><td>gauss</td><td>1.534405e-01</td><td>0.000000e+00</td><td>--</td><td>False</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>jet-viewing-angle</td><td>deg</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>jet-bulk-factor</td><td>lorentz-factor*</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>redshift</td><td></td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>False</td><td>True</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139887429058032-398104').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139887429058032-398104').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [4, 5, 6], type: "optionalnum"}]
#     });
# });
# </script>
# converged=True
# calls=110
# mesg=
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.88                      │              Nfcn = 110              │
# │ EDM = 3.3e-06 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │       SOME Parameters at limit       │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │APPROXIMATE│NOT pos. def.│   FORCED   │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name  │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_0 │    280    │    40     │            │            │   10    │  10000  │       │
# │ 1 │ par_1 │  0.53e6   │  0.05e6   │            │            │ 100000  │  1e+08  │       │
# │ 2 │ par_2 │    7.2    │    0.6    │            │            │    0    │         │       │
# │ 3 │ par_3 │   53e3    │    7e3    │            │            │    1    │  1e+09  │       │
# │ 4 │ par_4 │   2.21    │   0.06    │            │            │   -10   │   10    │       │
# │ 5 │ par_5 │   3.90    │   0.11    │            │            │   -10   │   10    │       │
# │ 6 │ par_6 │  11.0e15  │  0.6e15   │            │            │3.16228e+15│ 1.1e+16 │       │
# │ 7 │ par_7 │   0.153   │   0.010   │            │            │    0    │         │       │
# └───┴───────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────┬─────────────────────────────────────────────────────────────────────────────────┐
# │       │     par_0     par_1     par_2     par_3     par_4     par_5     par_6     par_7 │
# ├───────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ par_0 │  1.39e+03  1.57e+06      4.37  1.78e+05      1.86      2.44  4.28e+10    -0.152 │
# │ par_1 │  1.57e+06  2.99e+09  1.03e+04  2.93e+08  2.21e+03   4.3e+03   8.4e+13      -322 │
# │ par_2 │      4.37  1.03e+04     0.371   1.7e+03    0.0174   0.00357 -6.67e+08  -0.00325 │
# │ par_3 │  1.78e+05  2.93e+08   1.7e+03     5e+07       315       576  8.11e+12     -42.9 │
# │ par_4 │      1.86  2.21e+03    0.0174       315   0.00313   0.00361  4.44e+07 -0.000245 │
# │ par_5 │      2.44   4.3e+03   0.00357       576   0.00361    0.0123  9.54e+07 -0.000151 │
# │ par_6 │  4.28e+10   8.4e+13 -6.67e+08  8.11e+12  4.44e+07  9.54e+07  2.76e+24 -1.79e+07 │
# │ par_7 │    -0.152      -322  -0.00325     -42.9 -0.000245 -0.000151 -1.79e+07  9.26e-05 │
# └───────┴─────────────────────────────────────────────────────────────────────────────────┘
# dof=17
# chisq=17.877196, chisq/red=1.051600 null hypothesis sig=0.396628
#
# best fit pars
# <i>Table length=12</i>
# <table id="table139886058476208-122448" class="table-striped table-bordered table-condensed">
# <thead><tr><th>model name</th><th>name</th><th>val</th><th>bestfit val</th><th>err +</th><th>err -</th><th>start val</th><th>fit range min</th><th>fit range max</th><th>frozen</th></tr></thead>
# <tr><td>jet_leptonic</td><td>gmin</td><td>2.783970e+02</td><td>2.783970e+02</td><td>3.726914e+01</td><td>--</td><td>2.783989e+02</td><td>1.000000e+01</td><td>1.000000e+04</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gmax</td><td>5.349704e+05</td><td>5.349704e+05</td><td>5.468746e+04</td><td>--</td><td>5.349663e+05</td><td>1.000000e+05</td><td>1.000000e+08</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>N</td><td>7.237438e+00</td><td>7.237438e+00</td><td>6.094553e-01</td><td>--</td><td>7.237391e+00</td><td>0.000000e+00</td><td>--</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>gamma_break</td><td>5.299415e+04</td><td>5.299415e+04</td><td>7.069659e+03</td><td>--</td><td>5.299423e+04</td><td>1.000000e+00</td><td>1.000000e+09</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p</td><td>2.211115e+00</td><td>2.211115e+00</td><td>5.596718e-02</td><td>--</td><td>2.211115e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>p_1</td><td>3.898054e+00</td><td>3.898054e+00</td><td>1.107387e-01</td><td>--</td><td>3.898049e+00</td><td>-1.000000e+01</td><td>1.000000e+01</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R</td><td>1.100000e+16</td><td>1.100000e+16</td><td>5.795534e+14</td><td>--</td><td>1.099993e+16</td><td>3.162278e+15</td><td>1.100000e+16</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>R_H</td><td>1.000000e+17</td><td>--</td><td>--</td><td>--</td><td>1.000000e+17</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>B</td><td>1.534405e-01</td><td>1.534405e-01</td><td>9.619512e-03</td><td>--</td><td>1.534407e-01</td><td>0.000000e+00</td><td>--</td><td>False</td></tr>
# <tr><td>jet_leptonic</td><td>theta</td><td>2.290000e+00</td><td>--</td><td>--</td><td>--</td><td>2.290000e+00</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>BulkFactor</td><td>2.500000e+01</td><td>--</td><td>--</td><td>--</td><td>2.500000e+01</td><td>1.000000e+00</td><td>--</td><td>True</td></tr>
# <tr><td>jet_leptonic</td><td>z_cosm</td><td>3.080000e-02</td><td>--</td><td>--</td><td>--</td><td>3.080000e-02</td><td>0.000000e+00</td><td>--</td><td>True</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886058476208-122448').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886058476208-122448').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2, 3, 4, 5, 6, 7, 8], type: "optionalnum"}]
#     });
# });
# </script>
# -------------------------------------------------------------------------
#
# ================================================================================

# %% [markdown]
# ## 3.4 Minuit-fit parameters table

# %%
best_fit_minuit.parameters.par_table
# Out:
# <Table length=12>
#  model name      name          par type      ... phys. bound. max  log  frozen
#    str12        str11           str19        ...     float64       bool  bool
# ------------ ----------- ------------------- ... ---------------- ----- ------
# jet_leptonic        gmin  low-energy-cut-off ...     1.000000e+09 False  False
# jet_leptonic        gmax high-energy-cut-off ...     1.000000e+15 False  False
# jet_leptonic           N    emitters_density ...               -- False  False
# jet_leptonic gamma_break    turn-over-energy ...     1.000000e+09 False  False
# jet_leptonic           p   LE_spectral_slope ...     1.000000e+01 False  False
# jet_leptonic         p_1   HE_spectral_slope ...     1.000000e+01 False  False
# jet_leptonic           R         region_size ...     1.000000e+30 False  False
# jet_leptonic         R_H     region_position ...               -- False   True
# jet_leptonic           B      magnetic_field ...               -- False  False
# jet_leptonic       theta   jet-viewing-angle ...               -- False   True
# jet_leptonic  BulkFactor     jet-bulk-factor ...               -- False   True
# jet_leptonic      z_cosm            redshift ...               -- False   True

# %% [markdown]
# # 4. Furhter analysis from the fit

# %% [markdown]
# ## 4.1 Energetic report

# %%
fit_model_lsb.jet_leptonic.energetic_report()
# Out:
# <i>Table length=37</i>
# <table id="table139886057389792-628460" class="table-striped table-bordered table-condensed">
# <thead><tr><th>name</th><th>type</th><th>units</th><th>val</th></tr></thead>
# <tr><td>U_e</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>6.682966e-03</td></tr>
# <tr><td>U_p_cold</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_B</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>9.367857e-04</td></tr>
# <tr><td>U_p</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_p_target</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_Synch</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>8.804076e-04</td></tr>
# <tr><td>U_Synch_DRF</td><td>Energy dens. disk rest. frame</td><td>erg / cm3</td><td>3.453774e+02</td></tr>
# <tr><td>U_Disk</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_BLR</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_DT</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_CMB</td><td>Energy dens. blob rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_Disk_DRF</td><td>Energy dens. disk rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_BLR_DRF</td><td>Energy dens. disk rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_DT_DRF</td><td>Energy dens. disk rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>U_CMB_DRF</td><td>Energy dens. disk rest. frame</td><td>erg / cm3</td><td>0.000000e+00</td></tr>
# <tr><td>L_Sync_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>1.337754e+40</td></tr>
# <tr><td>L_SSC_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>3.644167e+39</td></tr>
# <tr><td>L_EC_Disk_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>L_EC_BLR_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>L_EC_DT_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>L_EC_CMB_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>L_pp_gamma_rf</td><td>Lum. blob rest. frme.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_Sync</td><td>jet Lum.</td><td>erg / s</td><td>2.090241e+42</td></tr>
# <tr><td>jet_L_SSC</td><td>jet Lum.</td><td>erg / s</td><td>5.694010e+41</td></tr>
# <tr><td>jet_L_EC_Disk</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_EC_BLR</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_EC_DT</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_EC_CMB</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_pp_gamma</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_rad</td><td>jet Lum.</td><td>erg / s</td><td>2.659642e+42</td></tr>
# <tr><td>jet_L_kin</td><td>jet Lum.</td><td>erg / s</td><td>4.756171e+43</td></tr>
# <tr><td>jet_L_tot</td><td>jet Lum.</td><td>erg / s</td><td>5.688832e+43</td></tr>
# <tr><td>jet_L_e</td><td>jet Lum.</td><td>erg / s</td><td>4.756171e+43</td></tr>
# <tr><td>jet_L_B</td><td>jet Lum.</td><td>erg / s</td><td>6.666969e+42</td></tr>
# <tr><td>jet_L_p_cold</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>jet_L_p</td><td>jet Lum.</td><td>erg / s</td><td>0.000000e+00</td></tr>
# <tr><td>BulkLorentzFactor</td><td></td><td></td><td>2.500000e+01</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table139886057389792-628460').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table139886057389792-628460').dataTable({
#         order: [],
#         pageLength: 100,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [3], type: "optionalnum"}]
#     });
# });
# </script>

# %% [markdown]
# ## 4.2 Montecarlo Markov Chain run

# %%
from jetset.mcmc import McmcSampler
mcmc=McmcSampler(model_minimizer_lsb)
# No beaming because it is imposed in the fit
labels=['B','R','p','p_1','gamma_break','gmin','gmax']
model_name='jet_leptonic'
use_labels_dict={model_name:labels}
mcmc.run_sampler(nwalkers=128,burnin=10,steps=50,bound=5.0,bound_rel=True,threads=None,walker_start_bound=0.005,use_labels_dict=use_labels_dict)
# Out:
# mcmc run starting
#   0%|          | 0/50 [00:00<?, ?it/s]
# /home/aramis/miniconda3/envs/jetset1.2/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# mcmc run done, with 1 threads took 603.36 seconds

# %% [markdown]
# ## Corner plots between parameters g0,s,B and N,B,s

# %%
f=mcmc.corner_plot()

# %%
p=mcmc.plot_model(sed_data=sed_data,fit_range=[10.5,27.4],size=50)
p.rescale(y_min=-13,x_min=6,x_max=28.5)
